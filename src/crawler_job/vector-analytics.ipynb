# %% [markdown]
# # Build Vector

# %%
import pandas as pd
import json
import requests

from datetime import datetime
from bs4 import BeautifulSoup

# %%
df = pd.read_json('./items.jl', lines=True)

# %%
df.head()
# Out:
#                                   link  appearences
# 0          https://scrapethissite.com/            0
# 1          https://scrapethissite.com/            0
# 2    https://scrapethissite.com/pages/            0
# 3  https://scrapethissite.com/lessons/            0
# 4      https://scrapethissite.com/faq/            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   link         20 non-null     object
#  1   appearences  20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 448.0+ bytes

# %% [markdown]
# ## Creating Vector for each link

# %%
# Load json lines to a dict-list

rows = []

with open('./items.jl') as f:

    for line in f:

        rows.append(json.loads(line))

# %%
i = 0

for row in rows:
    
    print(f'Processed link {i} of {len(rows)-1}')
    
    # Make a GET request to fetch the raw HTML content
    response = requests.get(row['link'])
    
    html_content = response.text

    # Parse the html content
    soup = BeautifulSoup(html_content, "lxml")
    
    # Vector #1 - URL character Length
    row['qty_character_url'] = len(row['link'])

    # Vector #2: Page Title Character Length
    row['qty_character_page_title'] = 0 if soup.html.head == None else len(soup.html.head.title.text)
    
    # Vector #3: Page href http(s) qty
    row['qty_page_http_links'] = len([t for t in soup.find_all('a') if 'http' in t.get('href',[]) ])
    
    # Vector #4: Page internal links qty
    row['qty_page_internal_links'] = len([t for t in soup.find_all('a')  if 'http' not in t.get('href',[])])
    
    # Vector #5: Qty a html tag
    row['qty_total_a'] = len(soup.find_all('a'))
    
    # Vector #6: Qty <table>
    row['qty_total_table'] = len(soup.find_all("table"))
    
    # Vector #7: Qty tr
    row['qty_total_table_tr'] = len(soup.find_all("tr"))
    
    # Vector #8: Qty table td
    row['qty_total_table_td'] = len(soup.find_all("td"))
    
    # Vector #9: Response Size
    row['qty_bytes_response'] = len(response.content)
    
    # Vector #10: Qty Page H1
    row['qty_h1_page'] = len(soup.find_all("h1"))
    
    i += 1
    
df_enrichment = pd.DataFrame(rows)
# Out:
# Processed link 0 of 19
# Processed link 1 of 19
# Processed link 2 of 19
# Processed link 3 of 19
# Processed link 4 of 19
# Processed link 5 of 19
# Processed link 6 of 19
# Processed link 7 of 19
# Processed link 8 of 19
# Processed link 9 of 19
# Processed link 10 of 19
# Processed link 11 of 19
# Processed link 12 of 19
# Processed link 13 of 19
# Processed link 14 of 19
# Processed link 15 of 19
# Processed link 16 of 19
# Processed link 17 of 19
# Processed link 18 of 19
# Processed link 19 of 19

# %%
df_enrichment.head(20)
# Out:
#                                                  link  appearences  \
# 0                         https://scrapethissite.com/            0
# 1                         https://scrapethissite.com/            0
# 2                   https://scrapethissite.com/pages/            0
# 3                 https://scrapethissite.com/lessons/            0
# 4                     https://scrapethissite.com/faq/            0
# 5                   https://scrapethissite.com/login/            0
# 6                   https://scrapethissite.com/pages/            0
# 7            https://scrapethissite.com/pages/simple/            0
# 8             https://scrapethissite.com/pages/forms/            0
# 9   https://scrapethissite.com/pages/ajax-javascript/            0
# 10           https://scrapethissite.com/pages/frames/            0
# 11         https://scrapethissite.com/pages/advanced/            0
# 12                https://scrapethissite.com/lessons/            0
# 13                   https://gum.co/oLpqb?wanted=true            2
# 14        https://gum.co/oLpqb/LASTCHANCE?wanted=true            2
# 15                    https://scrapethissite.com/faq/            0
# 16              https://scrapethissite.com/robots.txt            0
# 17                  https://scrapethissite.com/login/            0
# 18              https://peric.github.io/GetCountries/            1
# 19  https://scrapethissite.com/pages/forms/?page_n...            0
#
#     qty_character_url  qty_character_page_title  qty_page_http_links  \
# 0                  27                        61                    0
# 1                  27                        61                    0
# 2                  33                        82                    0
# 3                  35                        71                    4
# 4                  31                        90                    0
# 5                  33                        69                    0
# 6                  33                        82                    0
# 7                  40                       104                    1
# 8                  39                       109                    1
# 9                  49                       104                    1
# 10                 40                       106                    1
# 11                 42                       119                    0
# 12                 35                        71                    4
# 13                 32                        27                    6
# 14                 43                        27                    6
# 15                 31                        90                    0
# 16                 37                         0                    0
# 17                 33                        69                    0
# 18                 37                        14                    2
# 19                 50                       109                    1
#
#     qty_page_internal_links  qty_total_a  qty_total_table  qty_total_table_tr  \
# 0                         7            7                0                   0
# 1                         7            7                0                   0
# 2                        10           10                0                   0
# 3                         6           10                0                   0
# 4                         6            6                0                   0
# 5                         6            6                0                   0
# 6                        10           10                0                   0
# 7                         6            7                0                   0
# 8                        31           32                1                  26
# 9                        12           13                1                   1
# 10                        6            7                0                   0
# 11                        8            8                0                   0
# 12                        6           10                0                   0
# 13                        9           15                0                   0
# 14                        9           15                0                   0
# 15                        6            6                0                   0
# 16                        0            0                0                   0
# 17                        6            6                0                   0
# 18                        0            2                0                   0
# 19                       31           32                1                  26
#
#     qty_total_table_td  qty_bytes_response  qty_h1_page
# 0                    0                8117            1
# 1                    0                8117            1
# 2                    0               10603            1
# 3                    0               24164            1
# 4                    0                8968            1
# 5                    0                8314            0
# 6                    0               10603            1
# 7                    0              203362            1
# 8                  225               50435            1
# 9                    0               13210            1
# 10                   0               10337            1
# 11                   0                9871            0
# 12                   0               24164            1
# 13                   0              217163            1
# 14                   0              217320            1
# 15                   0                8968            1
# 16                   0                  49            0
# 17                   0                8314            0
# 18                   0                1864            1
# 19                 225               50452            1
